# %%
import os
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
pwd
# Out:
# '/home/rutvathaker/jupyter_notebook'

# %%
IMAGE_PATH = "1_4.jpg"

# %%
reader = easyocr.Reader(['en'])
array = reader.readtext(IMAGE_PATH,paragraph="False")
result = reader.readtext(IMAGE_PATH,paragraph="True", detail=0)
array
#result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [[[[93, 90], [703, 90], [703, 314], [93, 314]],
#   "GET FREE RENT TINSURANCE PLUS CASHBACK & OTHER BENEFITS WORIH23O00/ When you pay rent using your credit card on mb Zaelmorola Cotee Secure your Get up to Get up to Get exaiting  future rent {3,000/: {20,000/: reward points on payments cashbad partner € 'offers your Gedit card"],
#  [[[70, 486], [238, 486], [238, 516], [70, 516]], 'CREDIT CARD'],
#  [[[587, 510], [709, 510], [709, 581], [587, 581]], 'FxEE XENf JNSUXANCE'],
#  [[[69, 569], [257, 569], [257, 591], [69, 591]], '1254 2587 1024 3254'],
#  [[[71, 611], [145, 611], [145, 625], [71, 625]], 'Ayushmanm'],
#  [[[160, 903], [463, 903], [463, 939], [160, 939]],
#   'Log on to magicbricks conv/payrent'],
#  [[[48, 955], [528, 955], [528, 1062], [48, 1062]],
# ...

# %%
arr =[]
for i in array:
    arr.append(i[0])

# %%
arr
# Out:
# [[[93, 90], [703, 90], [703, 314], [93, 314]],
#  [[70, 486], [238, 486], [238, 516], [70, 516]],
#  [[587, 510], [709, 510], [709, 581], [587, 581]],
#  [[69, 569], [257, 569], [257, 591], [69, 591]],
#  [[71, 611], [145, 611], [145, 625], [71, 625]],
#  [[160, 903], [463, 903], [463, 939], [160, 939]],
#  [[48, 955], [528, 955], [528, 1062], [48, 1062]],
#  [[566, 966], [618, 966], [618, 974], [566, 974]],
#  [[611, 999], [681, 999], [681, 1043], [611, 1043]],
#  [[55, 1081], [131, 1081], [131, 1115], [55, 1115]],
#  [[159, 1085], [323, 1085], [323, 1117], [159, 1117]],
#  [[353, 1085], [517, 1085], [517, 1117], [353, 1117]],
#  [[560, 1057], [735, 1057], [735, 1113], [560, 1113]],
#  [[59, 1147], [527, 1147], [527, 1161], [59, 1161]]]

# %%
array[0][0]
# Out:
# [[93, 90], [703, 90], [703, 314], [93, 314]]

# %%
nested_lst_of_tuples = [tuple(l) for l in arr[1]]

# %%
nested_lst_of_tuples
# Out:
# [(70, 486), (238, 486), (238, 516), (70, 516)]

# %%
a = []
for t in range(len(arr)):
    a.append([tuple(l) for l in arr[t]])

# %%
a
# Out:
# [[(93, 90), (703, 90), (703, 314), (93, 314)],
#  [(70, 486), (238, 486), (238, 516), (70, 516)],
#  [(587, 510), (709, 510), (709, 581), (587, 581)],
#  [(69, 569), (257, 569), (257, 591), (69, 591)],
#  [(71, 611), (145, 611), (145, 625), (71, 625)],
#  [(160, 903), (463, 903), (463, 939), (160, 939)],
#  [(48, 955), (528, 955), (528, 1062), (48, 1062)],
#  [(566, 966), (618, 966), (618, 974), (566, 974)],
#  [(611, 999), (681, 999), (681, 1043), (611, 1043)],
#  [(55, 1081), (131, 1081), (131, 1115), (55, 1115)],
#  [(159, 1085), (323, 1085), (323, 1117), (159, 1117)],
#  [(353, 1085), (517, 1085), (517, 1117), (353, 1117)],
#  [(560, 1057), (735, 1057), (735, 1113), (560, 1113)],
#  [(59, 1147), (527, 1147), (527, 1161), (59, 1161)]]

# %%
nested_lst_of_tuples
# Out:
# [(93, 90), (703, 90), (703, 314), (93, 314)]

# %%
import pandas as pd
d = pd.DataFrame(a)
df = pd.DataFrame(array)
df.rename(columns={0:'Array', 1:'Text_Extracted'}, inplace=True)
df
# Out:
#                                                 Array  \
# 0        [[93, 90], [703, 90], [703, 314], [93, 314]]
# 1      [[70, 486], [238, 486], [238, 516], [70, 516]]
# 2    [[587, 510], [709, 510], [709, 581], [587, 581]]
# 3      [[69, 569], [257, 569], [257, 591], [69, 591]]
# 4      [[71, 611], [145, 611], [145, 625], [71, 625]]
# 5    [[160, 903], [463, 903], [463, 939], [160, 939]]
# 6    [[48, 955], [528, 955], [528, 1062], [48, 1062]]
# 7    [[566, 966], [618, 966], [618, 974], [566, 974]]
# 8   [[611, 999], [681, 999], [681, 1043], [611, 10...
# 9   [[55, 1081], [131, 1081], [131, 1115], [55, 11...
# 10  [[159, 1085], [323, 1085], [323, 1117], [159, ...
# 11  [[353, 1085], [517, 1085], [517, 1117], [353, ...
# 12  [[560, 1057], [735, 1057], [735, 1113], [560, ...
# 13  [[59, 1147], [527, 1147], [527, 1161], [59, 11...
#
#                                        Text_Extracted
# 0   GET FREE RENT TINSURANCE PLUS CASHBACK & OTHER...
# ...

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.7 MB 12.5 MB/s eta 0:00:01
# ...

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread(IMAGE_PATH)
res = reader.readtext(IMAGE_PATH)
print(image.shape)
leng=[]
brd=[]
for (bbox, text, prob) in res: 
  # unpack the bounding box
    (tl, tr, br, bl) = bbox
    
    tl = (int(tl[0]), int(tl[1]))
    tr = (int(tr[0]), int(tr[1]))
    br = (int(br[0]), int(br[1]))
    bl = (int(bl[0]), int(bl[1]))
#     print(tl)
    
    cv2.rectangle(image, tl, br, (0, 255, 0), 2)
    leng.append(tl)
    brd.append(br)
#     cv2.putText(image, text, (tl[0], tl[1] - 10),
#     cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)
# plt.rcParams['figure.figsize'] = (16,16)

cv2.imwrite('003.jpg',image)
# plt.imshow(image)
# Out:
# (480, 640, 3)
# True

# %%
image.shape
# Out:
# (592, 1292, 3)

# %% [raw]
# array[0][0]

# %%
brd
# Out:
# [(736, 72),
#  (139, 87),
#  (685, 81),
#  (730, 78),
#  (92, 94),
#  (76, 110),
#  (130, 110),
#  (527, 174),
#  (439, 215),
#  (743, 807),
#  (663, 852),
#  (357, 874),
#  (736, 873),
#  (163, 889),
#  (303, 885),
#  (637, 887),
#  (735, 889),
#  (547, 903),
#  (462, 930),
#  (57, 945),
#  (265, 945),
#  (589, 945),
#  (737, 945),
#  (65, 959),
#  (277, 959),
#  (589, 961),
#  (735, 959),
#  (41, 971),
#  (321, 973),
#  (465, 973),
#  (735, 973),
#  (333, 987),
#  (528, 1010),
#  (181, 1025),
#  (245, 1025),
#  (435, 1025),
#  (463, 1025),
#  (737, 1027),
#  (71, 1039),
#  (411, 1041),
#  (737, 1039),
#  (159, 1053),
#  (289, 1053),
#  (535, 1053),
#  (737, 1053),
#  (63, 1067),
#  (299, 1069),
#  (423, 1067),
#  (737, 1067),
#  (299, 1081),
#  (691, 1081),
#  (438, 1128),
#  (728, 1136),
#  (614, 1169),
#  (599, 644),
#  (335, 700),
#  (577, 760),
#  (350, 767),
#  (205, 889),
#  (336, 885),
#  (613, 945),
#  (97, 1040),
#  (185, 1054)]

# %%
print(leng)
# Out:
# [(574, 40), (11, 69), (643, 69), (696, 70), (28, 86), (28, 102), (80, 102), (166, 86), (258, 147), (729, 753), (85, 812), (13, 855), (369, 854), (15, 871), (207, 873), (337, 871), (643, 871), (203, 884), (286, 906), (13, 929), (67, 929), (269, 929), (615, 929), (13, 945), (71, 943), (283, 943), (595, 941), (13, 957), (45, 959), (325, 957), (469, 957), (13, 971), (218, 986), (9, 1011), (197, 1011), (251, 1009), (439, 1011), (467, 1009), (7, 1025), (105, 1023), (417, 1023), (13, 1039), (185, 1039), (295, 1039), (541, 1037), (7, 1053), (71, 1051), (305, 1053), (439, 1053), (7, 1066), (303, 1067), (18, 1098), (435, 1088), (134, 1140), (389, 617), (105, 671), (397, 705), (152, 749), (163, 866), (298, 872), (589, 927), (69, 1022), (159, 1037)]

# %%
print(brd)
# Out:
# [(736, 72), (139, 87), (685, 81), (730, 78), (92, 94), (76, 110), (130, 110), (527, 174), (439, 215), (743, 807), (663, 852), (357, 874), (736, 873), (163, 889), (303, 885), (637, 887), (735, 889), (547, 903), (462, 930), (57, 945), (265, 945), (589, 945), (737, 945), (65, 959), (277, 959), (589, 961), (735, 959), (41, 971), (321, 973), (465, 973), (735, 973), (333, 987), (528, 1010), (181, 1025), (245, 1025), (435, 1025), (463, 1025), (737, 1027), (71, 1039), (411, 1041), (737, 1039), (159, 1053), (289, 1053), (535, 1053), (737, 1053), (63, 1067), (299, 1069), (423, 1067), (737, 1067), (299, 1081), (691, 1081), (438, 1128), (728, 1136), (614, 1169), (599, 644), (335, 700), (577, 760), (350, 767), (205, 889), (336, 885), (613, 945), (97, 1040), (185, 1054)]

# %%
for i in brd:
    print(i[1])
# Out:
# 13
# 27
# 39
# 123
# 324
# 435
# 451
# 465
# 465
# 481
# 541
# 575
# 591
# 607
# 619
# 635
# 769
# 785
# 799
# 813
# 815
# 920
# 982
# 1121
# 1163
# 1236

# %%
area=[]
for i in brd:
    for j in leng:
        var=(i[0]-j[0]),(i[1]-j[1])
        area.append(var)

# %%
area
# Out:
# [(162, 32),
#  (725, 3),
#  (93, 3),
#  (40, 2),
#  (708, -14),
#  (708, -30),
#  (656, -30),
#  (570, -14),
#  (478, -75),
#  (7, -681),
#  (651, -740),
#  (723, -783),
#  (367, -782),
#  (721, -799),
#  (529, -801),
#  (399, -799),
#  (93, -799),
#  (533, -812),
#  (450, -834),
#  (723, -857),
#  (669, -857),
#  (467, -857),
#  (121, -857),
#  (723, -873),
#  (665, -871),
#  (453, -871),
#  (141, -869),
#  (723, -885),
#  (691, -887),
#  (411, -885),
#  (267, -885),
#  (723, -899),
#  (518, -914),
#  (727, -939),
#  (539, -939),
#  (485, -937),
#  (297, -939),
#  (269, -937),
#  (729, -953),
#  (631, -951),
#  (319, -951),
#  (723, -967),
#  (551, -967),
#  (441, -967),
#  (195, -965),
#  (729, -981),
#  (665, -979),
#  (431, -981),
#  (297, -981),
#  (729, -994),
#  (433, -995),
#  (718, -1026),
#  (301, -1016),
#  (602, -1068),
#  (347, -545),
#  (631, -599),
#  (339, -633),
#  (584, -677),
#  (573, -794),
#  (438, -800),
#  (147, -855),
#  (667, -950),
#  (577, -965),
# ...

# %%
area[1][0]*area[1][1]
# Out:
# 0

# %%
box_area=[]
for s in area:
    box_area.append(abs(s[0])*abs(s[1]))

# %%
sum(box_area)
# Out:
# 364738909

# %%
image.shape
# Out:
# (1237, 771, 3)

# %%
total_area=image.shape[0]*image.shape[1]
total_area
# Out:
# 901587

# %%
def extract_area():
    
    area=[]
    for i in boxes:
        
        area.append((i[2]-i[0])*(i[3]-i[1]))
    
    total_area=image.shape[0]*image.shape[1]
    return sum(area)/total_area

extract_area()

# %%
print(tl,br)
# Out:
# (175, 1196) (607, 1236)

# %%
height = image.shape[0]
width = image.shape[1]
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
#     plt.imshow(gray)
count = cv2.countNonZero(thresh)
area = count*0.8*0.8/(width*height)
print(area)
# Out:
# 0.6399375922040585

# %%
img = cv2.imread('07_1.jpg', cv2.IMREAD_UNCHANGED)
height = image.shape[0]
width = image.shape[1]
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
plt.imshow(gray)
count = cv2.countNonZero(thresh)
area = count*0.8*0.8/(width*height)
print(area)
# Out:
# 0.6399938742791511

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
img = cv2.imread(IMAGE_PATH)
img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
img = cv2.putText(img,text,bottom_right, font, 0.5,(0,255,0),2,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
# import the necessary packages
from easyocr import Reader
import argparse
import cv2

# %%
def cleanup_text(text):
	# strip out non-ASCII text so we can draw the text on the image
	# using OpenCV
	return "".join([c if ord(c) < 128 else "" for c in text]).strip()

# %%
# construct the argument parser and parse the arguments
ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", required=True)
# 	help="path to input image to be OCR'd")
ap.add_argument("-l", "--langs", type=str, default="en")
# 	help="comma separated list of languages to OCR")
ap.add_argument("-g", "--gpu", type=int, default=-1)
# 	help="whether or not GPU should be used")
args = vars(ap.parse_args())
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE [-l LANGS] [-g GPU]
# ipykernel_launcher.py: error: the following arguments are required: -i/--image
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# break the input languages into a comma separated list
langs = args["langs"].split(",")
print("[INFO] OCR'ing with the following languages: {}".format(langs))
# load the input image from disk
image = cv2.imread(args["image"])
# OCR the input image using EasyOCR
print("[INFO] OCR'ing input image...")
reader = Reader(langs, gpu=args["gpu"] > 0)
results = reader.readtext(image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # break the input languages into a comma separated list
# ----> 2 langs = args["langs"].split(",")
#       3 print("[INFO] OCR'ing with the following languages: {}".format(langs))
#       4 # load the input image from disk
#
# NameError: name 'args' is not defined
